# %%
import pandas as pd

# %%
plant_product_weekly_demand = pd.read_csv(r'data/processed/plant_product_weekly_demand.csv')

# %%
print("Plants:", plant_product_weekly_demand["Plant_ID"].nunique())
print("Products:", plant_product_weekly_demand["Product Card Id"].nunique())
print("Weeks:", plant_product_weekly_demand["Order_Date"].nunique())
# Out:
# Plants: 3
# Products: 118
# Weeks: 162

# %%
top_product_driver = pd.read_csv(r'data/processed/top_product_driver_weekly.csv')

# %%
top_product_driver.head()
# Out:
#   Plant_ID  Product Card Id                             Product Name  \
# 0       P1              365         Perfect Fitness Perfect Rip Deck
# 1       P1              191        Nike Men's Free 5.0+ Running Shoe
# 2       P1              403  Nike Men's CJ Elite 2 TD Football Cleat
# 3       P1              276        Under Armour Women's Ignite Slide
# 4       P1              172                Nike Women's Tempo Shorts
#
#    Order_Date  Weekly_Demand  Demand_Rank  Demand_Last_Week  Demand_Change  \
# 0  2015-01-04            306          1.0               NaN            NaN
# 1  2015-01-04            160          2.0               NaN            NaN
# 2  2015-01-04             77          3.0               NaN            NaN
# 3  2015-01-04             10          4.0               NaN            NaN
# 4  2015-01-04              6          5.0               NaN            NaN
#
#    Demand_Growth  Plant_Weekly_Demand  Demand_Contribution  \
# ...

# %%
top_product_driver.columns
# Out:
# Index(['Plant_ID', 'Product Card Id', 'Product Name', 'Order_Date',
#        'Weekly_Demand', 'Demand_Rank', 'Demand_Last_Week', 'Demand_Change',
#        'Demand_Growth', 'Plant_Weekly_Demand', 'Demand_Contribution',
#        'Demand_Contribution_Pct', 'Cumulative_Contribution'],
#       dtype='object')

# %%
inventory_risk_weekly = pd.read_csv(r'data/processed/inventory_risk_weekly.csv')

# %%
inventory_risk_weekly.columns
# Out:
# Index(['Plant_ID', 'Product Card Id', 'Product Name', 'Order_Date',
#        'Weekly_Demand', 'Initial_Inventory', 'Target_Coverage_Days',
#        'Average_Daily_Demand', 'Review_Cycle', 'Beginning_Inventory',
#        'Ending_Inventory', 'Replenishment_Qty', 'Target_Inventory',
#        'Safety_Stock_Days', 'Inventory_On_Hand', 'DOI', 'Inventory_Status',
#        'Reorder_Risk', 'ABC_Class', 'Inventory_Utilization',
#        'Inventory_Alert'],
#       dtype='object')

# %%
inventory_risk_weekly['Inventory_Alert']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7603    0
# 7604    0
# 7605    0
# 7606    0
# 7607    0
# Name: Inventory_Alert, Length: 7608, dtype: int64

# %%
inventory_risk_weekly[
    ['Reorder_Risk']
].describe()
# Out:
#        Reorder_Risk
# count          7608
# unique            2
# top              No
# freq           4356

# %%
service_risk = pd.read_csv(r'data/processed/service_risk_weekly.csv')

# %%
service_risk.columns
# Out:
# Index(['Plant_ID', 'Product Card Id', 'Product Name', 'Order_Date',
#        'Weekly_Demand', 'Initial_Inventory', 'Target_Coverage_Days',
#        'Average_Daily_Demand', 'Review_Cycle', 'Beginning_Inventory',
#        'Ending_Inventory', 'Replenishment_Qty', 'Target_Inventory',
#        'Safety_Stock_Days', 'Inventory_On_Hand', 'DOI', 'Inventory_Status',
#        'Reorder_Risk', 'ABC_Class', 'Inventory_Utilization', 'Inventory_Alert',
#        'Capacity_Status', 'Service_Risk', 'Service_Alert',
#        'Service_Risk_Score', 'Risk_Driver'],
#       dtype='object')

# %%
service_risk
# Out:
#      Plant_ID  Product Card Id                             Product Name  \
# 0          P2               19  Nike Men's Fingertrap Max Training Shoe
# 1          P2               19  Nike Men's Fingertrap Max Training Shoe
# 2          P2               19  Nike Men's Fingertrap Max Training Shoe
# 3          P2               19  Nike Men's Fingertrap Max Training Shoe
# 4          P2               19  Nike Men's Fingertrap Max Training Shoe
# ...       ...              ...                                      ...
# 7603       P1             1363                           Summer dresses
# 7604       P1             1363                           Summer dresses
# 7605       P1             1363                           Summer dresses
# 7606       P1             1363                           Summer dresses
# 7607       P1             1363                           Summer dresses
#
#       Order_Date  Weekly_Demand  Initial_Inventory  Target_Coverage_Days  \
# ...
